# %% [markdown]
# #### Piano Keyboard key color algorithm demo
#
# <p align="middle"><img src="../assets/keyboard-diagram-1.png" width="400" alt="Pinao Keyboard Diagram" /></p>
#
# This is a visual representation of the following file:
#
# https://github.com/MarkMoretto/python-examples-main/blob/master/algorithms/id_black_and_white_piano_keys.py

# %%
### We'll use the following modules for styling purposes only.
# from __future__ import print_function
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
from ipywidgets.widgets import HTML
import pandas as pd

# %% [markdown]
# First, we need three variables.  These will hold:
#
#     1. The "step" between groups.
#
#     2. The start of a two-key group.
#
#     3. The start of a three-key group.
#
# Looking at the diagram above, we can see that there's a single black key to the left at the 2 spot. Keys are numbered 1 - 88, which runs from lowest to highest notes.  The first two keys will be handled separately in the main function.

# %%
first_two_group = 5
first_three_group = 10
group_step = 12

# %% [markdown]
# Next, we have an incrementer class.
#
# This will take in a numeric value and increment those by a given step size and count. The output includes the initial starting point from which the calculaitons will be made.
#
# For example, if we start at 10 and want just the next two even numbers, we can call
# ``` python
# a = incrementer(10, 3)
# print(list(a))
# ```
#
# And the result will be:
# ``` python
# [10, 12, 14]
# ```

# %%
def incrementer(num, n_values=3, step=2):
    n = 0
    output = num
    while n < n_values:
        yield output
        output += step
        n += 1

# %% [markdown]
# Finally, we have our main function.  This is supposed to be a simple script, but we could probably break this into a few smaller chunks or even a class if if was going into production somehow.
#
# Annotations will be placed inside the function, where necessary.

# %%
def create_key_color_dict(verbose=False, key_dict = None):
    # Create a list of 88 keys starting at 1.
    keys = [i for i in range(1, 89)]
    
    # Create an empty dictionary for outputting results.
    if key_dict is None:
        ddict = {}

    # "Seed" our initial values with the first numbers for our two- and three-key sets.
    two_start = first_two_group
    three_start = first_three_group

    # We'll also seed our first two results with "W" for white and "B" for block
    # You can confirm placement from the provided diagram above.
    ddict[1] = "W"
    ddict[2] = "B"
    
    # We also have a "skip" list.  This is handy for when we generate incremental lists
    # and want to skip over certain values from our main iterator.
    to_skip = [1, 2]

    for k in keys:
        if not k in to_skip:
            # If the key equals the start of a three-key set
            if k == three_start:
                # Get a list of the three key numeric values with our incrementor function
                three_group = list(incrementer(three_start, 3))
                # Iterate over those numbers and set a dictionary entry to "B", for black key.
                for i in three_group:
                    ddict[i] = "B"
                    to_skip.append(i)
                
                # We'll update our three-key starting position by "stepping" ahead by our
                # aforementioned step amonut.  In this case, that would be 12 keys.
                three_start += group_step
    
            # The same process is repeated for the two-key groups.
            elif k == two_start:
                two_group = list(incrementer(two_start, 2))
                for i in two_group:
                    ddict[i] = "B"
                    to_skip.append(i)
    
                two_start += group_step
    
            else:
                # Otherwise, the dictionary entry should be "W", for white key
                ddict[k] = "W"
                
    # Before returning our dictionary, we will sort the keys in ascending order.
    return dict(sorted(ddict.items(), key=lambda x: x[0]))

# %%
key_color_dict = create_key_color_dict()

# Create a dataframe-friendly dictionary
df_dict = {"key_number":[], "color_id":[],}
for k, v in key_color_dict.items():
    df_dict["key_number"].append(k)
    df_dict["color_id"].append(v)


# create a dataframe from the dictionary
df = pd.DataFrame(df_dict)

def color_selector(col):
    piano_black = "#100c08"
    piano_white = "#fffafa"
    bg_color = piano_white if col == "W" else piano_black
    font_color = piano_black if col == "W" else piano_white
    return f"background-color: {bg_color};color: {font_color}"

# %%
# Apply to dataframe
df.style.applymap(color_selector, subset=["color_id"])
# Out:
# <style  type="text/css" >
#     #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row0_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row1_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row2_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row3_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row4_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row5_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row6_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row7_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row8_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row9_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row10_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row11_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row12_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row13_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row14_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row15_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row16_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row17_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row18_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row19_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row20_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row21_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row22_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row23_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row24_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row25_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row26_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row27_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row28_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row29_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row30_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row31_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row32_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row33_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row34_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row35_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row36_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row37_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row38_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row39_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row40_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row41_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row42_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row43_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row44_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row45_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row46_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row47_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row48_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row49_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row50_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row51_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row52_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row53_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row54_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row55_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row56_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row57_col1 {
#             background-color:  #100c08;
#             color:  #fffafa;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row58_col1 {
#             background-color:  #fffafa;
#             color:  #100c08;
#         }    #T_629a2c14_78ea_11ea_ac49_30e1717b40c6row59_col1 {
#             background
